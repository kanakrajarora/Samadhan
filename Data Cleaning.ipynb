# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('uttar_pradesh_grievances_dataset_updated.csv')
df.head()
# Out:
#   Grievance ID            Name     Contact              Email  \
# 0      G-00001  Shalini Tiwari  8626684731  user0@example.com
# 1      G-00002      Neha Singh  7825435601  user1@example.com
# 2      G-00003      Neha Singh  8284931938  user2@example.com
# 3      G-00004  Vikram Rathore  9248883589  user3@example.com
# 4      G-00005  Vikram Rathore  7314108674  user4@example.com
#
#                                          Description Submission Date  \
# 0  Violence in certain areas has escalated, with ...      2022-08-31
# 1  Garbage is not being collected regularly, lead...      2022-09-05
# 2  Violence in certain areas has escalated, with ...      2022-06-03
# 3  Road accidents have increased due to lack of p...      2022-05-19
# 4  Roads in the area are severely damaged, causin...      2022-10-10
#
#      Department        Category  Priority Sentiment   Location       Status  \
# 0  Municipality     Environment      High  Negative  Ghaziabad     Resolved
# ...

# %%
df.isnull()
# Out:
#       Grievance ID   Name  Contact  Email  Description  Submission Date  \
# 0            False  False    False  False        False            False
# 1            False  False    False  False        False            False
# 2            False  False    False  False        False            False
# 3            False  False    False  False        False            False
# 4            False  False    False  False        False            False
# ...            ...    ...      ...    ...          ...              ...
# 4995         False  False    False  False        False            False
# 4996         False  False    False  False        False            False
# 4997         False  False    False  False        False            False
# 4998         False  False    False  False        False            False
# 4999         False  False    False  False        False            False
#
#       Department  Category  Priority  Sentiment  Location  Status  \
# ...

# %%
df.isnull().any(axis=0)
# Out:
# Grievance ID              False
# Name                      False
# Contact                   False
# Email                     False
# Description               False
# Submission Date           False
# Department                False
# Category                  False
# Priority                  False
# Sentiment                 False
# Location                  False
# Status                    False
# Resolution Date            True
# Resolution Time (days)     True
# Feedback                   True
# dtype: bool

# %%
df.drop(columns = ['Resolution Date', 'Resolution Time (days)' , 'Feedback'], inplace = True)

# %%
df.head()
# Out:
#   Grievance ID            Name     Contact              Email  \
# 0      G-00001  Shalini Tiwari  8626684731  user0@example.com
# 1      G-00002      Neha Singh  7825435601  user1@example.com
# 2      G-00003      Neha Singh  8284931938  user2@example.com
# 3      G-00004  Vikram Rathore  9248883589  user3@example.com
# 4      G-00005  Vikram Rathore  7314108674  user4@example.com
#
#                                          Description Submission Date  \
# 0  Violence in certain areas has escalated, with ...      2022-08-31
# 1  Garbage is not being collected regularly, lead...      2022-09-05
# 2  Violence in certain areas has escalated, with ...      2022-06-03
# 3  Road accidents have increased due to lack of p...      2022-05-19
# 4  Roads in the area are severely damaged, causin...      2022-10-10
#
#      Department        Category  Priority Sentiment   Location       Status
# 0  Municipality     Environment      High  Negative  Ghaziabad     Resolved
# ...

# %%
df.drop(columns=['Grievance ID', 'Name', 'Contact', 'Email', 'Submission Date', 
                 'Department', 'Category', 'Priority', 'Sentiment', 
                 'Location', 'Status'], inplace=True)

# %%
df.head()
# Out:
#                                          Description
# 0  Violence in certain areas has escalated, with ...
# 1  Garbage is not being collected regularly, lead...
# 2  Violence in certain areas has escalated, with ...
# 3  Road accidents have increased due to lack of p...
# 4  Roads in the area are severely damaged, causin...

# %%
df.to_csv('cleaned_uttar_pradesh_grievances_dataset_updated.csv', index=False)
